# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("weather.csv")
df.head(16)
# Out:
#      outlook   temperature   humidity   windy  play
# 0      sunny            85         85   False    no
# 1      sunny            80         90    True    no
# 2   overcast            83         86   False   yes
# 3      rainy            70         96   False   yes
# 4      rainy            68         80   False   yes
# 5      rainy            65         70    True    no
# 6   overcast            64         65    True   yes
# 7      sunny            72         95   False    no
# 8      sunny            69         70   False   yes
# 9      rainy            75         80   False   yes
# 10     sunny            75         70    True   yes
# 11  overcast            72         90    True   yes
# 12  overcast            81         75   False   yes
# 13     rainy            71         91    True    no
# 14     rainy           100         70    True    no
# 15     sunny            45         70    True    no

# %%
df.head() # displays first 5 rows
# Out:
#     outlook   temperature   humidity   windy  play
# 0     sunny            85         85   False    no
# 1     sunny            80         90    True    no
# 2  overcast            83         86   False   yes
# 3     rainy            70         96   False   yes
# 4     rainy            68         80   False   yes

# %%
df.tail() # displays last 5 rows
# Out:
#      outlook   temperature   humidity   windy  play
# 11  overcast            72         90    True   yes
# 12  overcast            81         75   False   yes
# 13     rainy            71         91    True    no
# 14     rainy           100         70    True    no
# 15     sunny            45         70    True    no

# %%
df.count() # displays number of values for each column
# Out:
# outlook         16
#  temperature    16
#  humidity       16
#  windy          16
#  play           16
# dtype: int64

# %%
df.count()
# Out:
# outlook         16
#  temperature    16
#  humidity       16
#  windy          16
#  play           16
# dtype: int64

# %%
df.columns=['outlook','temperature','humidity','windy','play']

# %%
df[df['temperature']>70]
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny           85        85  False   no
# 1      sunny           80        90   True   no
# 2   overcast           83        86  False  yes
# 7      sunny           72        95  False   no
# 9      rainy           75        80  False  yes
# 10     sunny           75        70   True  yes
# 11  overcast           72        90   True  yes
# 12  overcast           81        75  False  yes
# 13     rainy           71        91   True   no
# 14     rainy          100        70   True   no

# %%
df1=df[df['temperature']>70]

# %%
print(type(df1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df1)
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny           85        85  False   no
# 1      sunny           80        90   True   no
# 2   overcast           83        86  False  yes
# 7      sunny           72        95  False   no
# 9      rainy           75        80  False  yes
# 10     sunny           75        70   True  yes
# 11  overcast           72        90   True  yes
# 12  overcast           81        75  False  yes
# 13     rainy           71        91   True   no
# 14     rainy          100        70   True   no

# %%
df2=df.query('temperature >70')
df2
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny           85        85  False   no
# 1      sunny           80        90   True   no
# 2   overcast           83        86  False  yes
# 7      sunny           72        95  False   no
# 9      rainy           75        80  False  yes
# 10     sunny           75        70   True  yes
# 11  overcast           72        90   True  yes
# 12  overcast           81        75  False  yes
# 13     rainy           71        91   True   no
# 14     rainy          100        70   True   no

# %%
df3=df.query("outlook == 'sunny' ")
print(df3)
# Out:
#    outlook  temperature  humidity  windy play
# 0    sunny           85        85  False   no
# 1    sunny           80        90   True   no
# 7    sunny           72        95  False   no
# 8    sunny           69        70  False  yes
# 10   sunny           75        70   True  yes
# 15   sunny           45        70   True   no

# %%
df3=df.query('outlook == "sunny"')
print(df3)
# Out:
#    outlook  temperature  humidity  windy play
# 0    sunny           85        85  False   no
# 1    sunny           80        90   True   no
# 7    sunny           72        95  False   no
# 8    sunny           69        70  False  yes
# 10   sunny           75        70   True  yes
# 15   sunny           45        70   True   no

# %%
df3.sort_values(by = 'temperature')
# Out:
#    outlook  temperature  humidity  windy play
# 15   sunny           45        70   True   no
# 8    sunny           69        70  False  yes
# 7    sunny           72        95  False   no
# 10   sunny           75        70   True  yes
# 1    sunny           80        90   True   no
# 0    sunny           85        85  False   no

# %%
df3.sort_values(by = 'temperature',ascending=False)
# Out:
#    outlook  temperature  humidity  windy play
# 0    sunny           85        85  False   no
# 1    sunny           80        90   True   no
# 10   sunny           75        70   True  yes
# 7    sunny           72        95  False   no
# 8    sunny           69        70  False  yes
# 15   sunny           45        70   True   no

# %%
df[['temperature','humidity']]
# Out:
#     temperature  humidity
# 0            85        85
# 1            80        90
# 2            83        86
# 3            70        96
# 4            68        80
# 5            65        70
# 6            64        65
# 7            72        95
# 8            69        70
# 9            75        80
# 10           75        70
# 11           72        90
# 12           81        75
# 13           71        91
# 14          100        70
# 15           45        70

# %% [markdown]
# iloc function has two parameters row and column
# frist part is row
# and second part is column

# %%
df.iloc[0: , 0:]
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny           85        85  False   no
# 1      sunny           80        90   True   no
# 2   overcast           83        86  False  yes
# 3      rainy           70        96  False  yes
# 4      rainy           68        80  False  yes
# 5      rainy           65        70   True   no
# 6   overcast           64        65   True  yes
# 7      sunny           72        95  False   no
# 8      sunny           69        70  False  yes
# 9      rainy           75        80  False  yes
# 10     sunny           75        70   True  yes
# 11  overcast           72        90   True  yes
# 12  overcast           81        75  False  yes
# 13     rainy           71        91   True   no
# 14     rainy          100        70   True   no
# 15     sunny           45        70   True   no

# %%
df.iloc[0: , 0:5]
# Out:
#      outlook  temperature  humidity  windy play
# 0      sunny           85        85  False   no
# 1      sunny           80        90   True   no
# 2   overcast           83        86  False  yes
# 3      rainy           70        96  False  yes
# 4      rainy           68        80  False  yes
# 5      rainy           65        70   True   no
# 6   overcast           64        65   True  yes
# 7      sunny           72        95  False   no
# 8      sunny           69        70  False  yes
# 9      rainy           75        80  False  yes
# 10     sunny           75        70   True  yes
# 11  overcast           72        90   True  yes
# 12  overcast           81        75  False  yes
# 13     rainy           71        91   True   no
# 14     rainy          100        70   True   no
# 15     sunny           45        70   True   no

# %%
df.iloc[0:5 , 0:]
# Out:
#     outlook  temperature  humidity  windy play
# 0     sunny           85        85  False   no
# 1     sunny           80        90   True   no
# 2  overcast           83        86  False  yes
# 3     rainy           70        96  False  yes
# 4     rainy           68        80  False  yes

# %%
df.iloc[1:5 , 0:]
# Out:
#     outlook  temperature  humidity  windy play
# 1     sunny           80        90   True   no
# 2  overcast           83        86  False  yes
# 3     rainy           70        96  False  yes
# 4     rainy           68        80  False  yes

# %%
df.iloc[1:5 ,[0,2]]
# Out:
#     outlook  humidity
# 1     sunny        90
# 2  overcast        86
# 3     rainy        96
# 4     rainy        80

# %%
df.iloc[1:5 ,0:2]
# Out:
#     outlook  temperature
# 1     sunny           80
# 2  overcast           83
# 3     rainy           70
# 4     rainy           68

# %%
df.loc[1:4 ,['outlook','humidity']]
# Out:
#     outlook  humidity
# 1     sunny        90
# 2  overcast        86
# 3     rainy        96
# 4     rainy        80

# %%
df[['temperature']]
# Out:
#     temperature
# 0            85
# 1            80
# 2            83
# 3            70
# 4            68
# 5            65
# 6            64
# 7            72
# 8            69
# 9            75
# 10           75
# 11           72
# 12           81
# 13           71
# 14          100
# 15           45

# %%
df.iloc[0:,[1]]
# Out:
#     temperature
# 0            85
# 1            80
# 2            83
# 3            70
# 4            68
# 5            65
# 6            64
# 7            72
# 8            69
# 9            75
# 10           75
# 11           72
# 12           81
# 13           71
# 14          100
# 15           45

# %%
df_temp=df[['temperature']]

# %%
df_temp.mean()
# Out:
# temperature    73.4375
# dtype: float64

# %%
df_temp.var()
# Out:
# temperature    138.395833
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-133-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# temperature    73.4375
# humidity       80.1875
# windy           0.5000
# dtype: float64

# %%
df_temp.median()
# Out:
# temperature    72.0
# dtype: float64

# %%
df_temp.describe()
# Out:
#        temperature
# count    16.000000
# mean     73.437500
# std      11.764176
# min      45.000000
# 25%      68.750000
# 50%      72.000000
# 75%      80.250000
# max     100.000000

# %%
df.describe()
# Out:
#        temperature  humidity
# count    16.000000  16.00000
# mean     73.437500  80.18750
# std      11.764176  10.36802
# min      45.000000  65.00000
# 25%      68.750000  70.00000
# 50%      72.000000  80.00000
# 75%      80.250000  90.00000
# max     100.000000  96.00000

# %%
df.mean()
# Out:
# <ipython-input-110-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# temperature    73.4375
# humidity       80.1875
# windy           0.5000
# dtype: float64

# %%
df_temp.boxplot()

# %%
df.boxplot(column=['temperature','humidity'])

# %%
df.boxplot(column=['temperature','humidity','windy'])

# %%
df.hist(column=['temperature'],bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7facc5e15610>]],
#       dtype=object)

# %%
df.hist(column=['temperature','humidity'],bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7facc5d90430>,
# ...
#       dtype=object)

# %%
df.plot.scatter(x='temperature', y='humidity')

# %%
df.corr()
# Out:
#              temperature  humidity     windy
# temperature     1.000000  0.163256 -0.170096
# humidity        0.163256  1.000000 -0.317518
# windy          -0.170096 -0.317518  1.000000

# %%
df[['temperature','humidity']].corr()
# Out:
#              temperature  humidity
# temperature     1.000000  0.163256
# humidity        0.163256  1.000000

# %%
a=df[['temperature','humidity']].corr()

# %%
print(type(a))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
corr=a.to_numpy()

# %%
corr
# Out:
# array([[1.        , 0.16325574],
#        [0.16325574, 1.        ]])

# %%
plt.imshow(corr)

# %% [markdown]
# cmap in python

# %%
plt.imshow(corr,cmap='autumn')

# %%
heatmap=plt.imshow(corr,cmap='Greens')
plt.colorbar(heatmap)

# %%
x=[[np.random.random() for i in range(10)] for j in range(10)]
x
# Out:
# [[0.932262210220345,
#   0.7625463120338946,
#   0.6829088726864593,
#   0.2138745704604722,
#   0.5878014606830763,
#   0.9466521753209397,
#   0.6673681291025976,
#   0.6035763827209812,
#   0.7957047523149997,
#   0.10713609283748526],
#  [0.8246272388984959,
#   0.8708131487838942,
#   0.7030306841267762,
#   0.911509341742239,
#   0.3847471229932353,
#   0.7151667207642202,
#   0.9470945022588064,
#   0.021207563456805745,
#   0.8194810550172539,
#   0.25522934913519935],
#  [0.585469660668555,
#   0.035888943130234274,
#   0.23982812468446157,
#   0.39019327961711525,
#   0.5755446924560886,
#   0.031022281339940116,
#   0.24927310077041887,
#   0.4426077400780658,
#   0.27755614245615057,
#   0.8221548338673915],
#  [0.5980068101544066,
#   0.2769569811193955,
#   0.16293309938485145,
#   0.3528822115560106,
#   0.7508560380458934,
#   0.8920686447523225,
#   0.322632032691897,
#   0.48155121125409506,
#   0.8571296658734788,
#   0.17421581518398277],
#  [0.5495504828865776,
# ...

# %%
heatmap2=plt.imshow(x, cmap='Oranges')
plt.colorbar(heatmap2)
