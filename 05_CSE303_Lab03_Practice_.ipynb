# %%
def mean(l):
  sum=0
  for i in l:
    sum+=i
  length=len(l)
  return sum/length

# %%
import math
def Standard_deviation(l):
  s=0
  m=mean(l)
  for i in range(len(l)):
    s+=(l[i]-m)**2
  s/=(len(l)-1)
  return math.sqrt(s)

# %% [markdown]
# ![PEARSON’S CORRELATION COEFFICIENT.JPG](data:image/jpeg;base64,...)

# %%
def pearson(x,y):
 xmean=mean(x)
 ymean=mean(y)
 sum=0
 for i in range(len(x)):
  sum+=((x[i]-xmean)*(y[i]-ymean))
 return sum/((len(x)-1)*Standard_deviation(x)*Standard_deviation(y))

# %%
x=[43,21,25,42,57,59]
y=[99,65,79,75,87,81]
pearson(x,y)
# Out:
# 0.5298089018901744

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
x1=[1,2,3,4,5,6]
x2=[3,6,9,12,15,18]
plt.scatter(x1,x2, color='r')

# %%
x2=[10,20,30,40,50,60]
y2=[60,50,40,30,20,10]
plt.scatter(x2,y2, color='green')
